# %% [markdown]
# # Setings
#
# Bibliotecas usadas:
#
# - datetime
# - pandas
#
# - sys
# - json
# - glob
#
# - Youtube-dl (https://youtube-dl.org/)

# %%
# Bibliotecas usadas

import os
import pandas as pd

import sys
import datetime
import json
import glob

# %%
# Diretórios e locais de trabalho
## dirbase = os.chdir("") incluir sua base de trabalho

cwd = os.getcwd()
print(cwd)
# Out:
# /Users/dumoura/Dev/PDev/Political_Remix/data/links

# %%
#Base_dir
BASE_DIR = os.path.dirname(cwd) # base de trabalho
DATA_DIR = os.path.join(BASE_DIR, "data") # dados gerais levantados durante projeto
META_DIR = os.path.join(BASE_DIR, "metadados") #metadados levantados durante projeto
SAMPLE_DIR = os.path.join(DATA_DIR, "sample") # material em processo - pode ser apagado ao final, caso julgue necessário
INPUTS_DIR = os.path.join(SAMPLE_DIR, "inputs") # local de trabalho para processamento de dados de midia 
OUTPUTS_DIR = os.path.join(SAMPLE_DIR, "outputs") # local de trabalho para processamento de dados de midia 

#Vids and links
VIDS_DIR = os.path.join(DATA_DIR, "vids") # dados gerais levantados durante projeto
LINK_DIR = os.path.join(DATA_DIR, "links") 

#Inputs
VID_DIR = os.path.join(INPUTS_DIR, "vid_input") # local de trabalho para processamento de dados de midia 
AUDIO_DIR = os.path.join(INPUTS_DIR, "audio_input") # local de trabalho para processamento de dados de midia # # Criar diretórios e locais de trabalho
LGG_DIR = os.path.join(INPUTS_DIR, "lgg_input") # local de trabalho para processamento de dados de midia 

#Outputs
FRAME_DIR = os.path.join(OUTPUTS_DIR, "thumbnails") # local de trabalho para processamento de dados de midia 
SONG_DIR = os.path.join(OUTPUTS_DIR, "songs") # local de trabalho para processamento de dados de midia # # Criar diretórios e locais de trabalho
LYRIC_DIR = os.path.join(OUTPUTS_DIR, "lyrics") # local de trabalho para processamento de dados de midia 

#Make_dirs
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(META_DIR, exist_ok=True)
os.makedirs(SAMPLE_DIR, exist_ok=True)
os.makedirs(INPUTS_DIR, exist_ok=True)
os.makedirs(OUTPUTS_DIR, exist_ok=True)

#Make_vids
os.makedirs(VIDS_DIR, exist_ok=True)
os.makedirs(LINK_DIR, exist_ok=True)

##Make_dirs inputs
os.makedirs(VID_DIR , exist_ok=True)
os.makedirs(AUDIO_DIR, exist_ok=True)
os.makedirs(LGG_DIR, exist_ok=True)

##Make_dirs outputs
os.makedirs(FRAME_DIR, exist_ok=True)
os.makedirs(SONG_DIR, exist_ok=True)
os.makedirs(LYRIC_DIR, exist_ok=True)

# %%
# Verificar se os diretórios e locais de trabalho foram criados corretamente
#os.listdir(BASE_DIR)

# %%
# Definir contexto -período- de trabalho 

now = datetime.datetime.now()
year = datetime.datetime.now().year
day = datetime.datetime.now().day
month = datetime.datetime.now().month

# Usar contexto para nomear documentos

context = f"_{month}-{day}-{year}"

# %%
#print(context)

# %% [markdown]
# ## Levantar metadados de vídeos de um lista de links
#
# - Selecionar link de corpus
# - Levantar os metadados de cada vídeo - base: links de vídeos / ferramenta: youtube-dl
# - Criar documento único
# - Criar Data Frame
# - Salvar documento em .csv

# %%
# Levantar dados/documentos diretório 
os.listdir(LINK_DIR)
# Out:
# ['Links_YTPBr.csv', '.DS_Store', 'Links_YTPBr.rtf']

# %%
doc_path = LINK_DIR
doc_name = 'Links_YTPBr.csv'
link = f'{doc_path}/{doc_name}'

# %%
os.chdir(LINK_DIR)
os.system(f"youtube-dl -a {LINK_DIR}/{doc_name} --id --write-info-json -i --skip-download")
# Out:
# 0

# %%
# Criar documento único
## listar em diretório todos os documentos terminados em '.json'

json_dir = LINK_DIR
json_root = os.path.join(json_dir, "*.json")
file_list = glob.glob(json_root)

len(file_list)
# Out:
# 88

# %%
# Criar documento único
## 1. a partir de lista de documentos '.json' estabelecer um único documento json - 'merge_file2021.json'

results = []

for f in file_list: 
    with open(f, 'r') as infile:
        json_file = json.load(infile)
        results.append(json_file)

# %%
# Criar documento único
## 2. a partir de lista de documentos '.json' estabelecer um único documento json - 'merge_file2021.json'

with open('merge_file.json', 'w') as outfile:
    json.dump(results, outfile)

# %%
# Criar documento único
## 3. a partir de lista de documentos '.json' estabelecer um único documento json - 'merge_file2021.json'

with open("merge_file.json") as f:
  data = json.load(f)

# %%
# Criar Data Frame
## a partir do documento json - 'merge_file2021.json', criar Data Frame
### key value pairs / json: videoId, uploader, uploader_id, uploader_url, channel_id, channel_url, upload_date, license, creator, title, description, categories, tags, duration, age_limit, annotations, chapters, videoLink, view_count, like_count, dislike_count, average_rating, is_live, start_time, end_time, series, playlist, playlist_index
## salvar Data Frame na pasta metadados - META_DIR

df_merged_data = []

for d in data:
        videoId = d['id']
        uploader = str.lower(d['uploader'])
        uploader_id = d['uploader_id']
        uploader_url = d['uploader_url']
        channel_id = d['channel_id']
        channel_url = d['channel_url']
        upload_date = d['upload_date']
        license = d['license']
        creator = d['creator']
        title = str.lower(d['title'])
        description = str.lower(d['description'])
        categories = d['categories']
        tags = d['tags']
        duration = d['duration']
        age_limit = d['age_limit']
        annotations = d['annotations']
        chapters = d['chapters']
        videoLink = d['webpage_url']
        view_count = d['view_count']
        like_count = d['like_count']
        dislike_count = d['dislike_count']
        average_rating = d['average_rating']
        is_live = d['is_live']
        start_time = d['start_time']
        end_time = d['end_time']
        series = d['series']
        playlist = d['playlist']
        playlist_index = d['playlist_index']
        
        df_merged_data.append((videoId, uploader, uploader_id, uploader_url, channel_id, channel_url, upload_date, license, creator, title, description, categories, tags, duration, age_limit, annotations, chapters, videoLink, view_count, like_count, dislike_count, average_rating, is_live, start_time, end_time, series, playlist, playlist_index))
        
df_merged_data = pd.DataFrame(df_merged_data, columns=['videoId', 'uploader', 'uploader_id', 'uploader_url', 'channel_id', 'channel_url', 'upload_date', 'license', 'creator', 'title', 'description', 'categories', 'tags', 'duration', 'age_limit', 'annotations', 'chapters', 'videoLink', 'view_count', 'like_count', 'dislike_count', 'average_rating', 'is_live', 'start_time', 'end_time', 'series', 'playlist', 'playlist_index'])
df_merged_data.upload_date = pd.to_datetime(df_merged_data.upload_date)

df_merged_data.to_csv(f"{META_DIR}/YTPBR_Metadata{context}.csv")

# %%
#verificar documento criado
title = f"YTPBR_Metadata{context}.csv"
df = pd.read_csv(f"{META_DIR}/{title}")
len(df)
# Out:
# 88

# %%
# Apagar em cache os documentos anteriores

dircache = os.chdir(LINK_DIR)
RESET = os.listdir(dircache) 

for item in RESET:
    if item.endswith(".json"):
        os.remove(item)

# %% [markdown]
# # Explorar documentos

# %%
df.head()
# Out:
#    Unnamed: 0      videoId       uploader    uploader_id  \
# 0           0  hPfKfczj5m8   bomberpooper   bomberpooper
# 1           1  1jO_kYSVnCM   bomberpooper   bomberpooper
# 2           2  HNTQsPi7WVQ  lucas乙anziğau  lucaszanzigau
# 3           3  q72ncJCMcYM   bomberpooper   bomberpooper
# 4           4  iFHqZsYKpWk   bomberpooper   bomberpooper
#
#                                 uploader_url                channel_id  \
# 0   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
# 1   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
# 2  http://www.youtube.com/user/lucaszanzigau  UCL7GARNiJPYwjkfJRUZZ2Tw
# 3   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
# 4   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
#
#                                          channel_url upload_date  license  \
# 0  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2020-10-09      NaN
# 1  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2021-01-08      NaN
# 2  http://www.youtube.com/channel/UCL7GARNiJPYwjk...  2020-05-16      NaN
# 3  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2020-07-31      NaN
# 4  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2017-06-10      NaN
#
#       creator  ... view_count like_count dislike_count average_rating  \
# 0         NaN  ...     460081      34479         476.0       4.945530
# 1         NaN  ...      51803       7767          91.0       4.953678
# 2         NaN  ...       3082        397           3.0       4.970000
# 3         NaN  ...     127991      15342         190.0       4.951069
# 4  Eurythmics  ...     812941      41189         724.0       4.930904
#
#    is_live  start_time  end_time  series                playlist  \
# 0      NaN         NaN       NaN     NaN   bomberpooper - Videos
# 1      NaN         NaN       NaN     NaN   bomberpooper - Videos
# 2      NaN         NaN       NaN     NaN  Lucas乙anziĞau - Videos
# 3      NaN         NaN       NaN     NaN   bomberpooper - Videos
# 4      NaN         NaN       NaN     NaN   bomberpooper - Videos
#
#    playlist_index
# 0              27
# 1              10
# 2              28
# 3              22
# 4              18
#
# [5 rows x 29 columns]

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.drop(['age_limit', 'chapters', 'is_live', 'start_time', 'end_time','series', 'playlist', 'playlist_index'], axis=1, inplace=True)

# %%
df.tail(5)
# Out:
#         videoId       uploader    uploader_id  \
# 83  KDwMM6iIJl0  lucas乙anziğau  lucaszanzigau
# 84  iR1bnHKQMWI   bomberpooper   bomberpooper
# 85  q5wXjO8xXs0   bomberpooper   bomberpooper
# 86  JF434pLNajU  lucas乙anziğau  lucaszanzigau
# 87  qweXy5KSwPw   bomberpooper   bomberpooper
#
#                                  uploader_url                channel_id  \
# 83  http://www.youtube.com/user/lucaszanzigau  UCL7GARNiJPYwjkfJRUZZ2Tw
# 84   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
# 85   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
# 86  http://www.youtube.com/user/lucaszanzigau  UCL7GARNiJPYwjkfJRUZZ2Tw
# 87   http://www.youtube.com/user/bomberpooper  UCKZK9dkmEba9MsGIfZ1kYjg
#
#                                           channel_url upload_date  license  \
# 83  http://www.youtube.com/channel/UCL7GARNiJPYwjk...  2021-01-11      NaN
# 84  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2018-09-30      NaN
# 85  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2021-01-02      NaN
# 86  http://www.youtube.com/channel/UCL7GARNiJPYwjk...  2020-12-24      NaN
# 87  http://www.youtube.com/channel/UCKZK9dkmEba9Ms...  2015-07-31      NaN
#
#    creator                                              title  \
# 83     NaN  troféu pooper  (06/01/2021) os melhores ytpbr'...
# 84     NaN   ytpbr - propagandas eleitorais que você não viu!
# 85     NaN   ytpbr - ilusões distorcidas do universo (remake)
# 86     NaN                                   jogando ho ho ho
# 87     NaN                      ytpbr - monogamia alternativa
#
#                                           description  categories  \
# 83  o troféu pooper é baseado no antigo golden key...  ['Comedy']
# 84  como é bonito esta historia!\najuda nois parça...  ['Comedy']
# 85  ☢seja membro do canal e ganhe benefícios:\nhtt...  ['Comedy']
# 86                       jogando aero the acro-bat 2.  ['Gaming']
# 87  um poop de chaves para a collab do vitorpooper...  ['Comedy']
#
#                                                  tags  duration  annotations  \
# 83                                          ['YTPBR']       510          NaN
# 84  ['Propagandas eleitorais', 'YTPBR eleição', 'e...       300          NaN
# 85  ['bomber', 'bomberpooper', 'bomber musica', 'b...       275          NaN
# 86                                                NaN      9648          NaN
# 87  ['chaves inédito', 'YTPBR', 'youtube poop br',...       215          NaN
#
#                                       videoLink  view_count  like_count  \
# 83  https://www.youtube.com/watch?v=KDwMM6iIJl0         319          50
# 84  https://www.youtube.com/watch?v=iR1bnHKQMWI      466826       36829
# 85  https://www.youtube.com/watch?v=q5wXjO8xXs0      185896       20609
# 86  https://www.youtube.com/watch?v=JF434pLNajU         321          47
# 87  https://www.youtube.com/watch?v=qweXy5KSwPw     1223758       48505
#
#     dislike_count  average_rating
# 83            2.0        4.846154
# 84          936.0        4.900861
# 85          189.0        4.963650
# 86            NaN        5.000000
# 87         1251.0        4.899429
